# %% [markdown]
# # PHÂN TÍCH MỨC ĐỘ PHỤ THUỘC AI CỦA LẬP TRÌNH VIÊN

# %% [markdown]
# Tên đề tài
# “Phân tích mức độ sử dụng và phụ thuộc vào AI của lập trình viên”
#
# Môn học: Khai phá dữ liệu
#
# Mục tiêu:
#
# Phân tích mức độ sử dụng AI
#
# Xây dựng AI Dependency Score
#
# Phân cụm lập trình viên theo mức độ phụ thuộc AI

# %% [markdown]
# ## MÔ TẢ DỮ LIỆU

# %% [markdown]
# Nguồn dataset (Stack Overflow Survey)
#
# Kích thước dữ liệu (số dòng, số cột)
#
# Mô tả nhóm cột liên quan đến AI

# %%
df = pd.read_csv("survey_results_public.csv")

df.head()
